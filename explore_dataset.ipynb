# %% [markdown]
# # Explore Dataset

# %%
# Open pickle and view dataframe
import pandas as pd
import pickle

data_path = '240125_aragorn_video.pkl'

with open(data_path, 'rb') as f:
    data = pickle.load(f)

data
# Out:
#        date  session_num  subject  trial_num  block  condition  correct  \
# 0    240125            0  aragorn          1      1          1        1
# 1    240125            0  aragorn          2      1          1        0
# 2    240125            0  aragorn          3      1          1        1
# 3    240125            0  aragorn          4      1          1        0
# 4    240125            0  aragorn          5      1          1        1
# ..      ...          ...      ...        ...    ...        ...      ...
# 635  240125            0  aragorn        636      4          2        1
# 636  240125            0  aragorn        637      1          1        1
# 637  240125            0  aragorn        638      1          1        1
# 638  240125            0  aragorn        639      1          1        1
# 639  240125            0  aragorn        640      1          1        1
#
#      error  error_type                            behavioral_code_markers  \
# ...

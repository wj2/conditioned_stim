# %% [markdown]
# # Explore Dataset

# %%
# Open pickle and view dataframe
import pandas as pd
import pickle

data_path = 'C:/Users/rober/Desktop/Analysis_Pipeline/240110_aragorn_video.pkl'

with open(data_path, 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#        date  session_num  subject  trial_num  block  condition  correct  \
# 0    240110            0  aragorn          1      1          1        0
# 1    240110            0  aragorn          2      1          1        0
# 2    240110            0  aragorn          3      1          1        1
# 3    240110            0  aragorn          4      1          1        1
# 4    240110            0  aragorn          5      1          1        1
# ..      ...          ...      ...        ...    ...        ...      ...
# 582  240110            0  aragorn        583      2          2        1
# 583  240110            0  aragorn        584      2          2        0
# 584  240110            0  aragorn        585      2          2        0
# 585  240110            0  aragorn        586      2          2        0
# 586  240110            0  aragorn        587      2          2        0
#
#      error  error_type                            behavioral_code_markers  \
# ...
